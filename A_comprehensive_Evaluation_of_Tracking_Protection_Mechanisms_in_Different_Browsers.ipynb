# %% [markdown]
# <a href="https://colab.research.google.com/github/ZAhmaad/Differential-Analysis---Web-Storage/blob/main/A_comprehensive_Evaluation_of_Tracking_Protection_Mechanisms_in_Different_Browsers.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Introduction

# %% [markdown]
# Modern web applications increasingly make use of different mechanisms to identify and authenticate users on the internet. The more the web application logic is pushed from the server to the client, however, the more sensitive data have to be handled at the client side rather than at the server side. Unfortunately, the traditional approach to handle client-side storage on the Web, i.e., HTTP cookies suffer from significant shortcomings: cookies are limited in size, have an unconventional semantics and are inconvenient to access programmatically. The HTML5 standard thus introduced the Web Storage API, which retains the intuitive flavor of cookies, while addressing their most relevant shortcomings.
#
#
#
# In order to detect and mitigate the tracking behavior of client-side storage on the Web, various countermeasures have been developed in the form of browser extensions or even protection mechanisms that are integrated directly in the browser. To evaluate the effectiveness of these defense mechanism, we will analyze the tracking behavior of the web storage across different browsers and anti-tracking extensions. A differential analysis will be conducted to automatically evaluate the enforcement of the policies in different browsers and extensions imposed to the tracking behavior of the web storage.

# %% [markdown]
# # Research Questions

# %% [markdown]
# • What is the behavior of the current tracking prevention techniques in modern browsers to detect and mitigate tracking involving web storage?
#
#
# • What is the behavior of the anti-tracking chrome extensions to detect and mitigate tracking involving web storage?
#
#
# • How the websites bypass the tracking prevention techniques and anti-tracking extensions in case of web storage?

# %% [markdown]
# # List of Browsers and Extensions

# %% [markdown]
# Broswer names and versions:
#
#         Chrome : Version 108.0.5359.124
#         Firefox: Version 109.0.1
#         Safari:  Version 15.2
#         Brave:   Version 147.186
#
#
# Extension names and versions (Only in case of Chrome):
#
#         Ghostery:        Version 8.9.8
#         Disconnect:      Version 20.3.1.1
#         Dockduckgo:      Version 2023.1.12
#         Privacypagder:   Version 2022.9.27
#         scripsafe:       Version 1.0.9.3
#
# Note: The selection list is based on number of users.

# %% [markdown]
# # Framework

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # **Comparision of StorageFlows and CookieFlows in Four browsers**
#
#
# # Total No of sites: 100
# # Sites after removing errors = 68
# # Sites with timeout errors = 20-30
#
#
#
#
# ![Flow_comparision.png](data:image/png;base64,...)

# %% [markdown]
# # **No of sites with at least one flow**
#
#
# ![No of sites with at least one flow.png](data:image/png;base64,...)

# %% [markdown]
# # **Top five trackers**
#
#
#
# ![No of sites with by max no of trackers.png](data:image/png;base64,...)

# %% [markdown]
# # ** Top 5 sites with max number of trackers**
#
#
#
# ![Top 5 sites.png](data:image/png;base64,...)

# %% [markdown]
# # **Same site Tracking and Same site Cross Domain Tracking**
#
#
#
# ![Combined_Tracking.png](data:image/png;base64,...)

# %% [markdown]
# # **Flow Comparison Pairwise**
#
#
#
# ![Flow comparison pairwise.png](data:image/png;base64,...)

# %% [markdown]
# # **Sites Comparison with at least one Flow pairwise**
#
# ![Sites with at least one flow pairwise.png](data:image/png;base64,...)

# %% [markdown]
# # **Sites with maximum number of Trackers**
#
# ![Sites with maximum number of Trackers.png](data:image/png;base64,...)

# %% [markdown]
# # **Same Site Tracking and Same Site Cross Domain Tracking**
#
#
# ![same and cross Tracking.png](data:image/png;base64,...)

# %% [markdown]
# # **Top Five Trackers Pairwise**
#
# ![Top 5 Trackers Pairwise.png](data:image/png;base64,...)

# %% [markdown]
# # **Trackers - Chrome vs Brave**

# %% [markdown]
# # **Cookie**
#
#
#
#  \begin{array}{|c|c|} \hline
# No & category & Entries    \\ \hline
# 1 & chromeCookieOnly  & '6sc.co',
#    'adnxs-simple.com',
#    'bizible.com',
#    'builder.io',
#    'datas3ntinel.com',
#    'doubleclick.net',
#    'facebook.com',
#    'google-analytics.com',
#    'google.com',
#    'google.it',
#    'hubspot.com',
#    'mail.ru',
#    'msn.com',
#    'mutinycdn.com',
#    'orangeclickmedia.com',
#    'sentry.io',
#    'simonsignal.com',
#    'siteimproveanalytics.io',
#    'stackadapt.com',
#    'wp.com',
#    'yandex.com',
#    'yandex.ru'
#    \\ \hline
# 2 & braveCookieOnly &    \\ \hline
# 3 & Both & 'drift.com',
#    'driftt.com',
#    'gbzu92.ru',
#    'microsoft.com',
#    'whitesaas.com',
#      \\ \hline
# \end{array}
#
#
# # **Storage**
#
#  \begin{array}{|c|c|} \hline
# No & category & Entries    \\ \hline
# 1 & chromeStorageOnly  &
#    'bugsnag.com',
#    'builder.io',
#    'creativecdn.com',
#    'datas3ntinel.com',
#    'mail.ru',
#    'mutinycdn.com',
#    'recaptcha.net',
#    'sentry.io',
#    'singular.net',
#    'yandex.com',
#    'yandex.ru'
#     \\ \hline
# 2 & braveStorageOnly &     \\ \hline
# 3 & Both &     \\ \hline
# \end{array}

# %% [markdown]
# # **Sites having  at least one Flow in chrome but no Flow in Brave**

# %% [markdown]
#  \begin{array}{|c|c|} \hline
# No & category & Entries    \\ \hline
# 1 & Cookie  &
#   'adobe.com',
#   'bing.com',
#   'opera.com',
#   'skype.com',
#   'ui.com',
#   'vimeo.com',
#   'wordpress.com',
#   'zoom.us',
#   \\ \hline
# 2 & Storage &  'fastly.net',
#   'frontapp.com',
#   'microsoft.com',
#   'nic.ru',
#   'opera.com',
#   'pinterest.com',
#   'vimeo.com',
#   'yandex.ru',
#   'zoom.us'   \\ \hline
# \end{array}

# %% [markdown]
# # **Trackers - Chrome vs Firefox**

# %% [markdown]
#  \begin{array}{|c|c|} \hline
# No & category & Entries    \\ \hline
# 1 & chromeCookieOnly  & '6sc.co',
#    'bizible.com',
#    'bizibly.com',
#    'google-analytics.com',
#    'mutinyhq.io',
#    'simonsignal.com',
#    'stackadapt.com' \\ \hline
# 2 & firefoxCookieOnly &  '33across.com',
#    'demdex.net',
#    'driftt.com',
#    'dzen.ru',
#    'intuitcdn.net',
#    'ispot.tv',
#    'liveperson.net',
#    'reson8.com',
#    'tiqcdn.com',
#    'ya.ru'   \\ \hline
# 3 & Both & 'adnxs.com',
#    'facebook.com',
#    'fullstory.com',
#    'hubspot.com',
#    'microsoft.com',
#    'mutinycdn.com',
#    'salesforceliveagent.com',
#    'sentry.io',
#    'siteimproveanalytics.io',
#    'speedcurve.com',
#    'wp.com',   \\ \hline
# \end{array}
#
#
# # **Storage**
#
#  \begin{array}{|c|c|} \hline
# No & category & Entries    \\ \hline
# 1 & chromeStorageOnly  &
#   'mutinyhq.io', 'singular.net' \\ \hline
# 2 & firefoxStorageOnly &  'bugsnag.com'   \\ \hline
# 3 & Both &  'creativecdn.com',
#    'fullstory.com',
#    'mutinycdn.com',
#    'salesforceliveagent.com',
#    'sentry.io'   \\ \hline
# \end{array}

# %% [markdown]
# # **Trackers - Chrome vs Safari**

# %% [markdown]
# # **Cookies**
#
#
#
#
#  \begin{array}{|c|c|} \hline
# No & category & Entries    \\ \hline
# 1 & chromeCookieOnly  & '6sc.co',
#    'adnxs.com',
#    'bizible.com',
#    'bizibly.com',
#    'google-analytics.com',
#    'mutinyhq.io',
#    'simonsignal.com',
#    'stackadapt.com' \\ \hline
# 2 & safariCookieOnly &  'drift.com', 'driftt.com', 'trustarc.com'   \\ \hline
# 3 & Both & 'facebook.com',
#    'fullstory.com',
#    'hubspot.com',
#    'microsoft.com',
#    'mutinycdn.com',
#    'salesforceliveagent.com',
#    'sentry.io',
#    'siteimproveanalytics.io',
#    'speedcurve.com',
#    'wp.com'   \\ \hline
# \end{array}
#
#
# # **Storage**
#
#  \begin{array}{|c|c|} \hline
# No & category & Entries    \\ \hline
# 1 & chromeStorageOnly  &
#   'mutinyhq.io', 'singular.net' \\ \hline
# 2 & safariStorageOnly &     \\ \hline
# 3 & Both &  'creativecdn.com',
#    'fullstory.com',
#    'mutinycdn.com',
#    'salesforceliveagent.com',
#    'sentry.io'   \\ \hline
# \end{array}

# %% [markdown]
# # **Sites having  at least one Flow in chrome but no Flow in Brave**

# %% [markdown]
#  \begin{array}{|c|c|} \hline
# No & category & Entries    \\ \hline
# 1 & Cookie  &
#   'frontapp.com',
#   'opera.com',
#   'skype.com',
#   'ui.com',
#   'vimeo.com',
#   'wordpress.com',
#   \\ \hline
# 2 & Storage &  'fastly.net', 'opera.com', 'vimeo.com',   \\ \hline
# \end{array}

# %% [markdown]
# # **Sites having at least one Flow in chrome but no Flow in Safari**

# %% [markdown]
#  \begin{array}{|c|c|} \hline
# No & category & Entries    \\ \hline
# 1 & Cookie  &
#   'vimeo.com'
#   \\ \hline
# 2 & Storage &  'vimeo.com',   \\ \hline
# \end{array}

# %% [markdown]
# # **Sites having at least one Flow in chrome but no Flow in Firefox**

# %% [markdown]
#  \begin{array}{|c|c|} \hline
# No & category & Entries    \\ \hline
# 1 & Cookie  &
#   'vimeo.com'
#   \\ \hline
# 2 & Storage &  'vimeo.com',   \\ \hline
# \end{array}

# %% [markdown]
# # Data Collection

# %% [markdown]
# We collect the 'key' and 'value' of the cookie, Local Storage and Session Storage and HTML content for the all the websites visiting four browsers mentioned above. In case of chrome, we will run two broswer instances. In case of first instance, the websites will visit two times while in case of second instance, the websites will visit once. For the rest of broswers, the websites will visit on the single instance.
#
# An informal representation of our database we collected is formulated below. The database comprises of three tables: "requests' , 'items' and 'contents'. The 'items' and 'contents' tables are in relation with 'requests' table through foreign key 'request.id'.
#
#
#
# 'REQUEST TABLE'
#
#  \begin{array}{|c|c|} \hline
# ID & User.agent & URL & redirect.url & status.code \\ \hline
# 1 & Chrome & a.com & a.com & 200 \\ \hline
# 2 & Chrome & a.com & a.com & 200 \\\hline
# 3 & ChromeFresh & a.com & a.com & 200\\ \hline
# 4 & Firefox & a.com & a.com & 200\\ \hline
# 5 & Safari & a.com & a.com & 200\\ \hline
# 6 & Brave & a.com & a.com & 200\\ \hline
# 7 &
# \end{array}
#
# 'ITEMS TABLE'
#
#  \begin{array}{|c|c|} \hline
# ID & request.id & type & key & value \\ \hline
# 1 & 1 & cookie & abc & 343545 \\ \hline
# 2 & 1 & local.storage & xyz & sddsad \\\hline
# 3 & 1 & session.storage & lang & en \\ \hline
# 4 & 2 & cookie & abc & 343545 \\ \hline
# 5 & 2 & local.storage & xyz & sddsad \\\hline
# 6 & 2 & session.storage & lang & en \\ \hline
# 7 &
# \end{array}
#
# 'CONTENTS TABLE'
#
#  \begin{array}{|c|c|} \hline
# ID & request.id & hash & Html.conteent \\ \hline
# 1 & 1 & kasdakdhasda & page.content.1  \\ \hline
# 2 & 2 & asdakjdkada & page.content.2  \\\hline
# 3 & 3 & kajsdahsdasdkjas & page.content.2 \\ \hline
# \end{array}
#
#
#
# A similar framework has been established to collect the same range of data from cookies, Local Storage and Session Storage in case of different extensions enforced in Chrome.

# %% [markdown]
# # Case-1:

# %% [markdown]
# - Counting the number of items (Ist_party_cookie, 3rd_party_cookie, Ist_party_local_storage, 3rdt_party_local_storage) which are same for every single redirect_url (two visits) in case of chrome and then checking out the difference in case of items when the same redirect_url visits the chromefresh (Fresh instance of chrome). If there's any difference we log the results. These results are further compared with other browsers (firefox, safari and brave) under the same the conditions mentioned above. The length of the value > 10 characters.

# %% [markdown]
# # Chrome vs firefox
#
#  \begin{array}{|c|c|} \hline
# No & Items & Potential.UIDs.in.Chrome & No.of.UIDs.present.in.FF & No.of.UIDs.blocked.in.FF & Script.loaded-No.UID & No.Script-No.UID & Ambigous.case  \\ \hline
# 1 & Ist.party.cookie & 1154 & 1123 & 31 & 20 & 00 & 11  \\ \hline
# 2 & Ist.party.local.storage & 437 & 417 & 20 & 00 & 00 & 00   \\ \hline
# 3 & 3rd.party.cookie & 725 & 689 & 36 & 12 & 24 & 00   \\ \hline
# 4 &  3rd.party.local.storage & 34  &  32 & 02 & 02 & 00 & 00   \\\hline
# \end{array}

# %% [markdown]
# # Chrome vs Safari
#
#  \begin{array}{|c|c|} \hline
# No & Items & Potential.UIDs.in.Chrome & No.of.UIDs.present.in.FF & No.of.UIDs.blocked.in.FF & Script.loaded-No.UID & No.Script-No.UID & Ambigous.case  \\ \hline
# 1 & Ist.party.cookie & 1218 & 1188 & 30 & 11 & 00 & 19  \\ \hline
# 2 & Ist.party.local.storage & 422 & 395 & 27 & 26 & 00 & 01    \\ \hline
# 3 & 3rd.party.cookie & 27 & 19 & 08 & 08 & 00 & 00   \\ \hline
# 4 &  3rd.party.local.storage & 34  &  21 & 13 & 11 & 02 & 00   \\\hline
# \end{array}

# %% [markdown]
# # Chrome vs Brave
#
#  \begin{array}{|c|c|} \hline
# No & Items & Potential.UIDs.in.Chrome & No.of.UIDs.present.in.FF & No.of.UIDs.blocked.in.FF & Script.loaded-No.UID & No.Script-No.UID & Ambigous.case  \\ \hline
# 1 & Ist.party.cookie & 1214 & 1071 & 143 & 143 & 00 & 04  \\ \hline
# 2 & Ist.party.local.storage & 463 & 383 & 80 & 77 & 00 & 03    \\ \hline
# 3 & 3rd.party.cookie & 47 & 18 & 29 & 00 & 29 & 00   \\ \hline
# 4 &  3rd.party.local.storage & 34  &  21 & 13 & 9 & 04 & 00   \\\hline
# \end{array}

# %% [markdown]
# # Case 2:
#
# Checking out the number of items in case of each of browser which are present in both cookie and local storage. The length of the value > 10 characters.

# %% [markdown]
# # Chrome:
#
#  \begin{array}{|c|c|} \hline
# No & Condition  & Same.items.count & Tracking  \\ \hline
# 1 & Ist.party.cookie- Ist.party.local.storage & 130 & First.party   \\ \hline
# 2 & Ist.party.cookie - 3rd.party.cookie & 44 & Third.Party  \\ \hline
# 3 & Ist.party.cookie- 3rd.party.local.storage & 01 & Third.Party   \\ \hline
# 2 & Ist.party.local.storage- 3rd.party.local.storage  & 22 & Third.Party    \\\hline
# 2 & 3rd.party.cookie - 3rd.party.local.storage  & 01 & Third.Party    \\\hline
# \end{array}

# %% [markdown]
# # Firefox
#
#  \begin{array}{|c|c|} \hline
# No & Condition  & Same.items.count & Tracking  \\ \hline
# 1 & Ist.party.cookie- Ist.party.local.storage & 145 & First.Party  \\ \hline
# 2 & Ist.party.cookie - 3rd.party.cookie & 43 & Third.Party  \\ \hline
# 3 & Ist.party.cookie- 3rd.party.local.storage & 00 & Third.Party   \\ \hline
# 2 & Ist.party.local.storage- 3rd.party.local.storage  & 01  & Third.Party   \\\hline
# 2 & 3rd.party.cookie - 3rd.party.local.storage  & 03 & Third.Party   \\\hline
# \end{array}

# %% [markdown]
# # Brave
#
#
#  \begin{array}{|c|c|} \hline
# No & Condition  & Same.items.count & Tracking  \\ \hline
# 1 & Ist.party.cookie- Ist.party.local.storage & 111 & First.Party   \\ \hline
# 2 & Ist.party.cookie - 3rd.party.cookie & 07 & Third.Party  \\ \hline
# 3 & Ist.party.cookie- 3rd.party.local.storage & 00 & Third.Party   \\ \hline
# 2 & Ist.party.local.storage- 3rd.party.local.storage  & 00 & Third.Party   \\\hline
# 2 & 3rd.party.cookie - 3rd.party.local.storage  & 00 & Third.Party   \\\hline
# \end{array}

# %% [markdown]
# # 3rd_party_cookie vs 3rd_party_localStorage

# %% [markdown]
# # Chrome

# %% [markdown]
# ![Screenshot 2023-03-13 at 1.30.41 PM.png](data:image/png;base64,...)

# %% [markdown]
# # Firefox

# %% [markdown]
# ![Screenshot 2023-03-13 at 1.34.25 PM.png](data:image/png;base64,...)

# %% [markdown]
# # Brave

# %% [markdown]
# # Ist_party-cookie vs Ist-party-local-storage

# %% [markdown]
# # Chrome

# %% [markdown]
# ![Screenshot 2023-03-13 at 1.39.06 PM.png](data:image/png;base64,...)

# %% [markdown]
# #

# %% [markdown]
# # Brave

# %% [markdown]
# ![Screenshot 2023-03-13 at 1.42.38 PM.png](data:image/png;base64,...)

# %% [markdown]
# # Firefox

# %% [markdown]
# ![Screenshot 2023-03-13 at 1.44.44 PM.png](data:image/png;base64,...)

# %% [markdown]
# # Third-party

# %% [markdown]
# # Brave

# %% [markdown]
# ![Screenshot 2023-03-13 at 1.59.29 PM.png](data:image/png;base64,...)

# %% [markdown]
# # Firefox

# %% [markdown]
# ![Screenshot 2023-03-13 at 1.55.20 PM.png](data:image/png;base64,...)

# %% [markdown]
# # *Chrome vs Firefox*

# %% [markdown]
# ![Screenshot 2023-03-13 at 1.53.03 PM.png](data:image/png;base64,...)

# %% [markdown]
# # *Chrome vs brave*

# %% [markdown]
# ![Screenshot 2023-03-13 at 1.55.20 PM.png](data:image/png;base64,...)

# %% [markdown]
# # CHROME VS ChromeFresh VS Brave

# %% [markdown]
# ![Screenshot 2023-02-15 at 2.37.59 PM.png](data:image/png;base64,...)

# %% [markdown]
# # CHROME VS ChromeFresh VS Firefox

# %% [markdown]
# ![Screenshot 2023-02-15 at 2.35.24 PM copy.png](data:image/png;base64,...)

# %% [markdown]
# # CHROME VS ChromeFresh VS Safari

# %% [markdown]
# ![Screenshot 2023-02-15 at 2.39.28 PM.png](data:image/png;base64,...)

# %% [markdown]
# # Chrome: Cookie_value = Local_storage_value

# %% [markdown]
# ![Screenshot 2023-02-15 at 2.42.31 PM.png](data:image/png;base64,...)

# %% [markdown]
# # Brave Statistics over top 50 sites

# %% [markdown]
#  \begin{array}{|c|c|} \hline
# No & request.id & Headless & Non-Headless \\ \hline
# 1 & total.sites & 50 & 50  \\ \hline
# 2 & Sites.rendered.successfully  & 33 & 33  \\\hline
# 3 & Time.elapsed & 00:17:29 & 00:18:20 \\ \hline
# 4 & Total.items & 393 & 385 \\ \hline
# 5 & total.items.in.both.cookie.n.local-storage & 12 & 8 \\ \hline
# \end{array}

# %% [markdown]
# # Chrome vs Firefox vs Brave (headless)

# %% [markdown]
#  \begin{array}{|c|c|} \hline
# No & request.id & Chrome & Firefox & Brave\\ \hline
# 1 & total.sites & 50 & 50 & 50 \\ \hline
# 2 & Sites.rendered.successfully  & 33 & 33 & 33 \\\hline
# 3 & No.of.items(values.same.in.two.chrome.but.diff.in.chromefresh) & 177 & 177 & 175 \\ \hline
# 4 & total.items.in.both.cookie.n.local-storage & 12 & 13 & 12 \\ \hline
# \end{array}

# %% [markdown]
# To check how many times a specific Broswer is being populated for the total number of  DISTINCT redirect_urls in case of cookie, local_storage, session_storage.
#
# QUERY:
#
#
#
#     -- SELECT user_agent,
#     -- COUNT(DISTINCT redirect_url) AS url_visited_count,
#     -- SUM(CASE WHEN type = 'cookie' THEN 1 ELSE 0 END) AS cookie_count,
#     -- SUM(CASE WHEN type = 'local_storage' THEN 1 ELSE 0 END) AS local_storage_count,
#     -- SUM(CASE WHEN type = 'session_storage' THEN 1 ELSE 0 END) AS session_storage_count
#     -- FROM requests
#     -- JOIN items ON requests.id = items.request_id
#     -- WHERE user_agent IN ('chrome','firefox','safari', 'brave')
#     -- GROUP BY user_agent;
#
#
#
# This is a SQL query that retrieves data from two tables (requests and items) and aggregates the data based on the user agent. The query returns the following information for each of the user agents (chrome, firefox, safari, and brave):
#
# - url_visited_count: the count of unique redirect URLs visited by the user agent, calculated using COUNT(DISTINCT redirect_url).
#
# - cookie_count, local_storage_count, session_storage_count: the sum of the number of items stored in the browser (cookies, local storage, and session storage, respectively) by the user agent, calculated using SUM and a CASE statement.
#
# The data is filtered by the user_agent column and only includes user agents in the list ('chrome','firefox','safari', 'brave'). The final result is grouped by the user_agent column.

# %% [markdown]
# ![Browsers.png](data:image/png;base64,...)

# %% [markdown]
# # CASE:2

# %% [markdown]
# To check how many times a Extension (in case of chrome) is being populated for the total number of DISTINCT redirect_urls in case of cookie, local_storage, session_storage.
#
# QUERY:
#
#
#
#     -- SELECT user_agent,
#     -- COUNT(DISTINCT redirect_url) AS url_visited_count,
#     -- SUM(CASE WHEN type = 'cookie' THEN 1 ELSE 0 END) AS cookie_count,
#     -- SUM(CASE WHEN type = 'local_storage' THEN 1 ELSE 0 END) AS local_storage_count,
#     -- SUM(CASE WHEN type = 'session_storage' THEN 1 ELSE 0 END) AS session_storage_count
#     -- FROM requests
#     -- JOIN items ON requests.id = items.request_id
#     -- WHERE user_agent IN ('Ghostery','Disconnect','Dockduckgo', 'Privacypagder', 'scripsafe')
#     -- GROUP BY user_agent;

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # CASE:3

# %% [markdown]
# A pairwise comparision of Chrome (with other Broswers one by one) to take the same key for every redirect_url visiting the pair of Broswers and then compare the corresponding 'value' that either it's same or not.
#
# QUERY:
#
#
#
#
#     -- SELECT DISTINCT i.key,
#     -- CASE
#     -- WHEN MIN(CASE WHEN r.user_agent = 'firefox' THEN i.value ELSE NULL END) = MIN(CASE WHEN r.user_agent = 'brave' THEN i.value ELSE NULL END) THEN 0
#     -- ELSE 1
#     -- END AS Value_Comparison,
#     -- MIN(CASE WHEN r.user_agent = 'firefox' THEN i.value ELSE NULL END) AS Firefox_Value,
#     -- MIN(CASE WHEN r.user_agent = 'brave' THEN i.value ELSE NULL END) AS Brave_Value
#     -- FROM
#     -- REQUESTS r
#     -- INNER JOIN items i
#     -- ON r.id = i.request_id
#     -- WHERE
#     -- i.type = 'local_storage' AND
#     -- (r.user_agent = 'firefox' OR r.user_agent = 'brave')
#     -- GROUP BY i.key;
#
# This is a SQL query that retrieves data from two tables (requests and items) and aggregates the data based on the item key. The query returns the following information:
#
# - key: the unique key of the item stored in the local storage of the browser.
#
# - Value_Comparison: a binary value indicating whether the value of the same key stored in firefox and brave is equal (0) or not equal (1).
#
# - Firefox_Value: the value of the key stored in firefox.
#
# - Brave_Value: the value of the key stored in brave.
#
# The data is filtered based on the type column to only include local storage items and the user_agent column to only include firefox and brave. The final result is grouped by the key column and returns the MIN value for the firefox and brave user agents for each key.
#
#     -- SELECT
#     -- i.type AS storage_type,
#     -- SUM(CASE WHEN Value_Comparison = 'Different' THEN 1 ELSE 0 END) AS Different,
#     -- SUM(CASE WHEN Value_Comparison = 'Same' THEN 1 ELSE 0 END) AS Same
#     -- FROM (
#     -- SELECT DISTINCT i.key, i.value, i.type,
#     -- CASE
#     -- WHEN MIN(CASE WHEN r.user_agent = 'chrome' THEN i.value ELSE NULL END) = MIN(CASE WHEN r.user_agent = 'brave' THEN i.value ELSE NULL END) THEN 'Same'
#     -- ELSE 'Different'
#     -- END AS Value_Comparison
#     -- FROM
#     -- REQUESTS r
#     -- INNER JOIN items i
#     -- ON r.id = i.request_id
#     -- WHERE
#     -- (r.user_agent = 'chrome' OR r.user_agent = 'brave')
#     -- AND (i.type = 'cookie' OR i.type = 'local_storage' OR i.type = 'session_storage')
#     -- GROUP BY i.key, i.type
#     -- ) i
#     -- GROUP BY i.type;
#
#
# This is a SQL query that retrieves data from two tables (requests and items) and aggregates the data based on the item type. The query returns the following information:
#
# - storage_type: the type of storage (cookie, local_storage, or session_storage).
#
# - Different: the number of keys that have different values stored in chrome and brave.
#
# - Same: the number of keys that have the same values stored in chrome and brave.
#
# The inner query retrieves the key, value, type, and a binary value (Same or Different) indicating whether the value of the same key stored in chrome and brave is equal or not. The outer query aggregates the data based on the type column and returns the sum of Different and Same for each type. The data is filtered based on the user_agent column to only include chrome and brave, and the type column to only include cookie, local_storage, or session_storage.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # CASE:4

# %% [markdown]
# A comparision of all Broswer by taking the same key in all Broswers for every DISTINCT redirect_url in case
# 'cookie' ,'local_storage and 'session_storage and checking that either value is same and Different
#
# QUERY:
#
#     - SELECT Value_Comparison, COUNT(Value_Comparison) as count
#     -- FROM (
#     -- SELECT DISTINCT i.key,
#     -- CASE
#     -- WHEN MIN(CASE WHEN r.user_agent = 'firefox' THEN i.value ELSE NULL END) = MIN(CASE WHEN r.user_agent = 'brave' THEN i.value ELSE NULL END) AND
#     -- MIN(CASE WHEN r.user_agent = 'firefox' THEN i.value ELSE NULL END) = MIN(CASE WHEN r.user_agent = 'safari' THEN i.value ELSE NULL END) AND
#     -- MIN(CASE WHEN r.user_agent = 'firefox' THEN i.value ELSE NULL END) = MIN(CASE WHEN r.user_agent = 'chrome' THEN i.value ELSE NULL END) THEN 'Same'
#     -- ELSE 'Different'
#     -- END AS Value_Comparison,
#     -- MIN(CASE WHEN r.user_agent = 'firefox' THEN i.value ELSE NULL END) AS Firefox_Value,
#     -- MIN(CASE WHEN r.user_agent = 'brave' THEN i.value ELSE NULL END) AS Brave_Value,
#     -- MIN(CASE WHEN r.user_agent = 'safari' THEN i.value ELSE NULL END) AS Safari_Value,
#     -- MIN(CASE WHEN r.user_agent = 'chrome' THEN i.value ELSE NULL END) AS Chrome_Value
#     -- FROM
#     -- REQUESTS r
#     -- INNER JOIN items i
#     -- ON r.id = i.request_id
#     -- WHERE
#     -- i.type = 'cookie' AND
#     -- (r.user_agent = 'firefox' OR r.user_agent = 'brave' OR r.user_agent = 'safari' OR r.user_agent = 'chrome')
#     -- GROUP BY i.key
#     -- )
#     -- GROUP BY Value_Comparison;
#
#
# This SQL query is joining the requests and items tables on id and request_id respectively. It then filters the results to only include rows where the user_agent is 'firefox', 'brave', 'safari', or 'chrome', and the type of item is 'cookie'.
#
# The query calculates the number of unique cookie keys that have the same value across all 4 browsers and the number of unique cookie keys that have different values across the 4 browsers. This is done by creating a new column Value_Comparison that has the value 'Same' when the value of the key is the same for all 4 browsers and 'Different' when the value is different for at least one of the browsers. The final result is a count of the number of keys that have 'Same' and 'Different' values.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # CASE:5

# %% [markdown]
#   A comparision of Ghostery Extension with the rest of Extensions (Disconnect, Dockduckgo, Privacypagder, scripsafe) by taking the same key for every DISTINCT redirect_url in case 'cookie' ,'local_storage and 'session_storage and checking that either value is same and Different
#
#
#
#
# QUERY:
#
#
#     --     SELECT
#     --     i.type AS storage_type,
#     --     SUM(CASE WHEN Value_Comparison = 'Different' THEN 1 ELSE 0 END) AS Different,
#     --     SUM(CASE WHEN Value_Comparison = 'Same' THEN 1 ELSE 0 END) AS Same
#     --     FROM (
#     --     SELECT DISTINCT i.key, i.value, i.type,
#     --     CASE
#     --     WHEN MIN(CASE WHEN r.user_agent = 'ghostery' THEN i.value ELSE NULL END) = MIN(CASE WHEN r.user_agent = 'disconnect' THEN i.value ELSE NULL END) THEN 'Same'
#     --     ELSE 'Different'
#     --     END AS Value_Comparison
#     --     FROM
#     --     REQUESTS r
#     --     INNER JOIN items i
#     --     ON r.id = i.request_id
#     --     WHERE
#     --     (r.user_agent = 'ghostery' OR r.user_agent = 'disconnect')
#     --     AND (i.type = 'cookie' OR i.type = 'local_storage' OR i.type = 'session_storage')
#     --     GROUP BY i.key, i.type
#     --     ) i
#     --     GROUP BY i.type;

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # CASE:6

# %% [markdown]
#   A comparision of scripsafe Extension with the rest of Extensions (Disconnect, Dockduckgo, Privacypagder, ghostery)
#     by taking the same key for every DISTINCT redirect_url in case 'cookie' ,'local_storage and 'session_storage and
#     checking that either value is same and Different
#
#
#
# QUERY:
#
#
#     --     SELECT
#     --     i.type AS storage_type,
#     --     SUM(CASE WHEN Value_Comparison = 'Different' THEN 1 ELSE 0 END) AS Different,
#     --     SUM(CASE WHEN Value_Comparison = 'Same' THEN 1 ELSE 0 END) AS Same
#     --     FROM (
#     --     SELECT DISTINCT i.key, i.value, i.type,
#     --     CASE
#     --     WHEN MIN(CASE WHEN r.user_agent = 'scriptsafe' THEN i.value ELSE NULL END) = MIN(CASE WHEN r.user_agent = 'disconnect' THEN i.value ELSE NULL END) THEN 'Same'
#     --     ELSE 'Different'
#     --     END AS Value_Comparison
#     --     FROM
#     --     REQUESTS r
#     --     INNER JOIN items i
#     --     ON r.id = i.request_id
#     --     WHERE
#     --     (r.user_agent = 'scriptsafe' OR r.user_agent = 'disconnect')
#     --     AND (i.type = 'cookie' OR i.type = 'local_storage' OR i.type = 'session_storage')
#     --     GROUP BY i.key, i.type
#     --     ) i
#     --     GROUP BY i.type;

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# CASE:7

# %% [markdown]
# A comparision of all Extensions (Chrome) by taking the same key in all Extensions for every DISTINCT redirect_url in case 'cookie' ,'local_storage and 'session_storage and checking that either value is same and Different.
#
#
# QUERY:
#
#
#
#     -- SELECT Value_Comparison, COUNT(Value_Comparison) as count
#     -- FROM (
#     -- SELECT DISTINCT i.key,
#     -- CASE
#     -- WHEN MIN(CASE WHEN r.user_agent = 'ghostery' THEN i.value ELSE NULL END) = MIN(CASE WHEN r.user_agent = 'disconnect' THEN i.value ELSE NULL END) AND
#     -- MIN(CASE WHEN r.user_agent = 'ghostery' THEN i.value ELSE NULL END) = MIN(CASE WHEN r.user_agent = 'duckduckgo' THEN i.value ELSE NULL END) AND
#     -- MIN(CASE WHEN r.user_agent = 'ghostery' THEN i.value ELSE NULL END) = MIN(CASE WHEN r.user_agent = 'privacybadger' THEN i.value ELSE NULL END) AND
#     -- MIN(CASE WHEN r.user_agent = 'ghostery' THEN i.value ELSE NULL END) = MIN(CASE WHEN r.user_agent = 'scriptsafe' THEN i.value ELSE NULL END) THEN 'Same'
#     -- ELSE 'Different'
#     -- END AS Value_Comparison,
#     -- MIN(CASE WHEN r.user_agent = 'ghostery' THEN i.value ELSE NULL END) AS ghostery_Value,
#     -- MIN(CASE WHEN r.user_agent = 'disconnect' THEN i.value ELSE NULL END) AS disconnect_Value,
#     -- MIN(CASE WHEN r.user_agent = 'duckduckgo' THEN i.value ELSE NULL END) AS duckduckgo_Value,
#     -- MIN(CASE WHEN r.user_agent = 'privacybadger' THEN i.value ELSE NULL END) AS privacybadger_Value,
#     -- MIN(CASE WHEN r.user_agent = 'scriptsafe' THEN i.value ELSE NULL END) AS scriptsafe_Value
#     -- FROM
#     -- REQUESTS r
#     -- INNER JOIN items i
#     -- ON r.id = i.request_id
#     -- WHERE
#     -- i.type = 'cookie' AND
#     -- (r.user_agent = 'ghostery' OR r.user_agent = 'disconnect' OR r.user_agent = 'duckduckgo' OR r.user_agent = 'privacybadger' OR r.user_agent='scriptsafe')
#     -- GROUP BY i.key
#     -- )
#     -- GROUP BY Value_Comparison;

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # CASE:8

# %% [markdown]
# We take the same keys for the two same redirect_url in case of Chrome and see if there corresponding values are same. Then we use the same condition to compare those values with values in case of ChromeFresh.
#
# Chrome:         a.com : k1: V1, k2: V2 \
# Chrome:         a.com: k1: V1, K2: V2`
#
# V! could be tracking
# ChromeFresh:    a.com: K1: V1`, K2: V2
#
#  \begin{array}{|c|c|} \hline
# type & different.values  \\ \hline
# cookie & 52   \\ \hline
# local_storage & 12   \\\hline
# session_storage & 8  \\ \hline
# \end{array}
